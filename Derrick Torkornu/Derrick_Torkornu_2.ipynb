# %%
from bs4 import BeautifulSoup
import requests
from urllib.request import urlopen

# %%
import cloudscraper

# %%
requests = cloudscraper.create_scraper()

# %%
website = requests.get("https://www.jumia.com.gh/phones-tablets/")

# %%
print(website)
# Out:
# <Response [403]>

# %%
first = soup.find_all("div",class_ = "name")

# %%
soup = BeautifulSoup(website.content)

# %%
first = soup.find_all("div",class_ = "name")

# %%
names = soup.find_all("h3",class_ = "name")

# %%
print(names)
# Out:
# [<h3 class="name">Lenovo LP40 Wireless Earphone Bluetooth 5.0 Waterproof Earphone Touch headset - Black</h3>, <h3 class="name">Lenovo XT90 In-ear Earphones 5.0 Headphones True Wireless Earbuds with Touch Control</h3>, <h3 class="name">Samsung Galaxy A03 Core - 32GB HDD - 2GB RAM Smartphone - Black</h3>, <h3 class="name">Lenovo LP40 Wireless Earphone Bluetooth 5.0 Waterproof Earphone Touch headset white</h3>, <h3 class="name">Nokia 105 (4th Edition) Dual SIM Feature Phone- Charcoal Black</h3>, <h3 class="name">Itel A16 Plus - 8GB HDD - 1GB RAM -  Phantom Black + Free Gifts</h3>, <h3 class="name">Itel It 2173 Dual SIM Feature Phone - 512MB ROM - 512MB RAM - Blue</h3>, <h3 class="name">Itel A16 Plus - 8GB HDD - 1GB RAM - Champagne Gold</h3>, <h3 class="name">Nokia C2-05 2GSM 2.0''  Slide Touch &amp;Type Mp3 Player Mobile Phone</h3>, <h3 class="name">X-INOVA Magic 6 Dual SIM Smartphone - 16GB HDD - 2GB RAM - Green</h3>, <h3 class="name">X-INOVA Magic 6 Dual SIM Smartphone - 16GB HDD - 2G
# ...

# %%
phone_names = [t.text.strip() for t in names]

# %%
print(phone_names)
# Out:
# ['Lenovo LP40 Wireless Earphone Bluetooth 5.0 Waterproof Earphone Touch headset - Black', 'Lenovo XT90 In-ear Earphones 5.0 Headphones True Wireless Earbuds with Touch Control', 'Samsung Galaxy A03 Core - 32GB HDD - 2GB RAM Smartphone - Black', 'Lenovo LP40 Wireless Earphone Bluetooth 5.0 Waterproof Earphone Touch headset white', 'Nokia 105 (4th Edition) Dual SIM Feature Phone- Charcoal Black', 'Itel A16 Plus - 8GB HDD - 1GB RAM -  Phantom Black + Free Gifts', 'Itel It 2173 Dual SIM Feature Phone - 512MB ROM - 512MB RAM - Blue', 'Itel A16 Plus - 8GB HDD - 1GB RAM - Champagne Gold', "Nokia C2-05 2GSM 2.0''  Slide Touch &Type Mp3 Player Mobile Phone", 'X-INOVA Magic 6 Dual SIM Smartphone - 16GB HDD - 2GB RAM - Green', 'X-INOVA Magic 6 Dual SIM Smartphone - 16GB HDD - 2GB RAM - Black', 'Nokia 105 (4th Edition) Dual SIM Cell Phone - Black', 'Itel 5081 Triple SIM Phone  Wireless FM Radio - Dark Blue', 'X Tigi T1 Mini - 1.77" - Dual SIM Cell Phone - 32MB HDD- 32MB RAM - Blue', 'Samsung Gal
# ...

# %% [markdown]
# len(phone_names)

# %%
len(phone_names)
# Out:
# 102

# %%
prices = soup.find_all("div",class_ = "prc")

# %%
phone_prices = [t.text.strip() for t in prices]

# %%
len(phone_prices)
# Out:
# 54

# %%
import pandas as pd

# %%
df = pd.DataFrame({"Laptop":phone_names[:54],"Price":phone_prices[:54]})

# %%
df
# Out:
#                                                Laptop       Price
# 0   Lenovo LP40 Wireless Earphone Bluetooth 5.0 Wa...   GH₵ 75.00
# 1   Lenovo XT90 In-ear Earphones 5.0 Headphones Tr...   GH₵ 52.80
# 2   Samsung Galaxy A03 Core - 32GB HDD - 2GB RAM S...  GH₵ 554.00
# 3   Lenovo LP40 Wireless Earphone Bluetooth 5.0 Wa...   GH₵ 62.00
# 4   Nokia 105 (4th Edition) Dual SIM Feature Phone...  GH₵ 104.00
# 5   Itel A16 Plus - 8GB HDD - 1GB RAM -  Phantom B...  GH₵ 251.00
# 6   Itel It 2173 Dual SIM Feature Phone - 512MB RO...   GH₵ 69.00
# 7   Itel A16 Plus - 8GB HDD - 1GB RAM - Champagne ...  GH₵ 251.00
# 8   Nokia C2-05 2GSM 2.0''  Slide Touch &Type Mp3 ...  GH₵ 139.00
# 9   X-INOVA Magic 6 Dual SIM Smartphone - 16GB HDD...  GH₵ 285.00
# 10  X-INOVA Magic 6 Dual SIM Smartphone - 16GB HDD...  GH₵ 290.00
# 11  Nokia 105 (4th Edition) Dual SIM Cell Phone - ...  GH₵ 105.00
# 12  Itel 5081 Triple SIM Phone  Wireless FM Radio ...   GH₵ 97.00
# ...

# %%
df.to_csv("Second_assignment.csv")

# %%
df
# Out:
#                                                Laptop       Price
# 0   Lenovo LP40 Wireless Earphone Bluetooth 5.0 Wa...   GH₵ 75.00
# 1   Lenovo XT90 In-ear Earphones 5.0 Headphones Tr...   GH₵ 52.80
# 2   Samsung Galaxy A03 Core - 32GB HDD - 2GB RAM S...  GH₵ 554.00
# 3   Lenovo LP40 Wireless Earphone Bluetooth 5.0 Wa...   GH₵ 62.00
# 4   Nokia 105 (4th Edition) Dual SIM Feature Phone...  GH₵ 104.00
# 5   Itel A16 Plus - 8GB HDD - 1GB RAM -  Phantom B...  GH₵ 251.00
# 6   Itel It 2173 Dual SIM Feature Phone - 512MB RO...   GH₵ 69.00
# 7   Itel A16 Plus - 8GB HDD - 1GB RAM - Champagne ...  GH₵ 251.00
# 8   Nokia C2-05 2GSM 2.0''  Slide Touch &Type Mp3 ...  GH₵ 139.00
# 9   X-INOVA Magic 6 Dual SIM Smartphone - 16GB HDD...  GH₵ 285.00
# 10  X-INOVA Magic 6 Dual SIM Smartphone - 16GB HDD...  GH₵ 290.00
# 11  Nokia 105 (4th Edition) Dual SIM Cell Phone - ...  GH₵ 105.00
# 12  Itel 5081 Triple SIM Phone  Wireless FM Radio ...   GH₵ 97.00
# ...
