# %%
import pandas as pd
# import pandas library
# !pip install pyreadstat

# install pyreadstat library. This will help us read the dataset in the spss file (1ResearchProjectData.sav)

# %%
scores = pd.read_spss('C:\\Users\\OMEN\\Desktop\\marcus\\PyDataGhana\\Pandas basic\\1ResearchProjectData.sav')
# read the spss file.

# %%
scores.head()
# get the first 5 rows
# Out:
#    Student Teacher  Gender            Ethnic    Freeredu  Score       wesson
# 0      1.0   Ruger  Female             Asian  Free lunch   76.0  Ruger_Smith
# 1      2.0   Ruger  Female          Hispanic  Paid lunch   56.0  Ruger_Smith
# 2      3.0   Ruger  Female  African-American  Free lunch   34.0  Ruger_Smith
# 3      4.0   Ruger  Female             Asian  Paid lunch   59.0  Ruger_Smith
# 4      5.0   Ruger    Male          Hispanic  Free lunch   73.0  Ruger_Smith

# %%
scores.info()
# info method gives the ff details of the dataset. 

# total number of records : 217
# number of column in dataset : 7
# 2 different Data types of columns ; category and float
# total number of non null entries in each variable (column)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217 entries, 0 to 216
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Student   216 non-null    float64
#  1   Teacher   216 non-null    category
#  2   Gender    216 non-null    category
#  3   Ethnic    216 non-null    category
#  4   Freeredu  216 non-null    category
#  5   Score     216 non-null    float64
#  6   wesson    217 non-null    category
# dtypes: category(5), float64(2)
# memory usage: 5.3 KB

# %%
scores.tail()
# get the last 5 rows
# Out:
#      Student Teacher  Gender            Ethnic    Freeredu  Score       wesson
# 212    213.0  Wesson    Male          Hispanic  Free lunch   94.0       Wesson
# 213    214.0  Wesson    Male          Hispanic  Paid lunch   91.0       Wesson
# 214    215.0  Wesson  Female  African-American  Paid lunch   53.0       Wesson
# 215    216.0  Wesson    Male          Hispanic  Paid lunch   57.0       Wesson
# 216      NaN     NaN     NaN               NaN         NaN    NaN  Ruger_Smith

# %%
scores
# by default pandas displays the 1st five rows and last five rows of a dataset if the number of rows in the dataset exceeds 60
# Out:
#      Student Teacher  Gender            Ethnic    Freeredu  Score       wesson
# 0        1.0   Ruger  Female             Asian  Free lunch   76.0  Ruger_Smith
# 1        2.0   Ruger  Female          Hispanic  Paid lunch   56.0  Ruger_Smith
# 2        3.0   Ruger  Female  African-American  Free lunch   34.0  Ruger_Smith
# 3        4.0   Ruger  Female             Asian  Paid lunch   59.0  Ruger_Smith
# 4        5.0   Ruger    Male          Hispanic  Free lunch   73.0  Ruger_Smith
# 5        6.0   Ruger    Male         Caucasian  Paid lunch   58.0  Ruger_Smith
# 6        7.0   Ruger  Female  African-American  Paid lunch   62.0  Ruger_Smith
# 7        8.0   Ruger    Male          Hispanic  Free lunch   40.0  Ruger_Smith
# 8        9.0   Ruger  Female  African-American  Free lunch   82.0  Ruger_Smith
# 9       10.0   Ruger    Male  African-American  Paid lunch   78.0  Ruger_Smith
# 10      11.0   Ruger    Male  African-American  Paid lunch   64.0  Ruger_Smith
# ...

# %%
# print(pd.options.display.max_rows) 
# 60

pd.options.display.max_rows = 9999 

# increase the default number of rows from 60 to 9999

scores

# display all rows
# Out:
#      Student Teacher  Gender            Ethnic    Freeredu  Score       wesson
# 0        1.0   Ruger  Female             Asian  Free lunch   76.0  Ruger_Smith
# 1        2.0   Ruger  Female          Hispanic  Paid lunch   56.0  Ruger_Smith
# 2        3.0   Ruger  Female  African-American  Free lunch   34.0  Ruger_Smith
# 3        4.0   Ruger  Female             Asian  Paid lunch   59.0  Ruger_Smith
# 4        5.0   Ruger    Male          Hispanic  Free lunch   73.0  Ruger_Smith
# 5        6.0   Ruger    Male         Caucasian  Paid lunch   58.0  Ruger_Smith
# 6        7.0   Ruger  Female  African-American  Paid lunch   62.0  Ruger_Smith
# 7        8.0   Ruger    Male          Hispanic  Free lunch   40.0  Ruger_Smith
# 8        9.0   Ruger  Female  African-American  Free lunch   82.0  Ruger_Smith
# 9       10.0   Ruger    Male  African-American  Paid lunch   78.0  Ruger_Smith
# 10      11.0   Ruger    Male  African-American  Paid lunch   64.0  Ruger_Smith
# ...

# %%
scores.isnull().sum()
# columns with null. It sums the total nulls in each columns. wesson column has no null value
# Out:
# Student     1
# Teacher     1
# Gender      1
# Ethnic      1
# Freeredu    1
# Score       1
# wesson      0
# dtype: int64

# %%
scores.shape
# 217 rows, 7 columns
# Out:
# (217, 7)

# %%
scores.dropna(inplace = True)
# drop all rows containing null values and change the original Dataframe
scores
# Out:
#      Student Teacher  Gender            Ethnic    Freeredu  Score       wesson
# 0        1.0   Ruger  Female             Asian  Free lunch   76.0  Ruger_Smith
# 1        2.0   Ruger  Female          Hispanic  Paid lunch   56.0  Ruger_Smith
# 2        3.0   Ruger  Female  African-American  Free lunch   34.0  Ruger_Smith
# 3        4.0   Ruger  Female             Asian  Paid lunch   59.0  Ruger_Smith
# 4        5.0   Ruger    Male          Hispanic  Free lunch   73.0  Ruger_Smith
# 5        6.0   Ruger    Male         Caucasian  Paid lunch   58.0  Ruger_Smith
# 6        7.0   Ruger  Female  African-American  Paid lunch   62.0  Ruger_Smith
# 7        8.0   Ruger    Male          Hispanic  Free lunch   40.0  Ruger_Smith
# 8        9.0   Ruger  Female  African-American  Free lunch   82.0  Ruger_Smith
# 9       10.0   Ruger    Male  African-American  Paid lunch   78.0  Ruger_Smith
# 10      11.0   Ruger    Male  African-American  Paid lunch   64.0  Ruger_Smith
# ...

# %%
scores.isnull().sum()
# no null values available
# Out:
# Student     0
# Teacher     0
# Gender      0
# Ethnic      0
# Freeredu    0
# Score       0
# wesson      0
# dtype: int64

# %%
scores['Method'] = scores['wesson'].apply(lambda x: 'Standard' if 'Ruger_Smith' in x else 'Traditional')
# create a copy of the wesson column and map its values ie replace Ruger_Smith with Standard and Wesson with traditional

# %%
scores
# Out:
#      Student Teacher  Gender            Ethnic    Freeredu  Score  \
# 0        1.0   Ruger  Female             Asian  Free lunch   76.0
# 1        2.0   Ruger  Female          Hispanic  Paid lunch   56.0
# 2        3.0   Ruger  Female  African-American  Free lunch   34.0
# 3        4.0   Ruger  Female             Asian  Paid lunch   59.0
# 4        5.0   Ruger    Male          Hispanic  Free lunch   73.0
# 5        6.0   Ruger    Male         Caucasian  Paid lunch   58.0
# 6        7.0   Ruger  Female  African-American  Paid lunch   62.0
# 7        8.0   Ruger    Male          Hispanic  Free lunch   40.0
# 8        9.0   Ruger  Female  African-American  Free lunch   82.0
# 9       10.0   Ruger    Male  African-American  Paid lunch   78.0
# 10      11.0   Ruger    Male  African-American  Paid lunch   64.0
# 11      12.0   Ruger  Female             Asian  Paid lunch   68.0
# 12      13.0   Ruger    Male          Hispanic  Free lunch   39.0
# ...

# %%
scores.groupby(['Method']).size()
# number of observations according to teaching method ie traditional and standard
# Out:
# Method
# Standard       140
# Traditional     76
# dtype: int64

# %%
scores.groupby(['Ethnic']).size()
# number of observations grouped according to ethnicity
# Out:
# Ethnic
# African-American    52
# Asian               53
# Caucasian           45
# Hispanic            66
# dtype: int64

# %%
scores.groupby(['Gender']).size()
# number of observations grouped according to gender
# Out:
# Gender
# Female     96
# Male      120
# dtype: int64
