# %%
from urllib.request import Request,urlopen
from bs4 import BeautifulSoup as bs
import bs4
import pandas as pd

# %%
url = 'https://www.jumia.com.gh/phones-tablets/'
request = Request(url, headers= {"User-Agent":"Mozilla/5.0"})

# %%
webpage = urlopen(request).read()

# %%
result =bs(webpage)

# %%
products= [item.get_text() for item in result.select(".core .name")]
len(products)
# Out:
# 138

# %%
price= [cost.get_text() for cost in result.select(".core .prc")]

# %%
df= pd.DataFrame({"Name":products,"Price":price})

# %%
solution = df[:130]

# %%
solution
# Out:
#                                                   Name       Price
# 0    Lenovo LP40 Wireless Earphone Bluetooth 5.0 Wa...   GH₵ 72.00
# 1    Lenovo LP40 Wireless Earphone Bluetooth 5.0 Wa...   GH₵ 72.00
# 2    Lenovo XT90 In-ear Earphones 5.0 Headphones Tr...   GH₵ 55.00
# 3                         P47 Wireless Headset - White   GH₵ 29.47
# 4    Universal Adjustable Desktop Tablet Stands Pho...   GH₵ 18.00
# 5    Itel A16 Plus - 8GB HDD - 1GB RAM -  Phantom B...  GH₵ 251.00
# 6    Samsung Galaxy A03 Core - 32GB HDD - 2GB RAM S...  GH₵ 554.00
# 7      P47 Wireless Foldable Bluetooth Headset - Black   GH₵ 33.00
# 8     F9-32 Stereo V5.1 Bluetooth Earphone Power Banks   GH₵ 51.00
# 9    ARHANORY Tripod Stand with LED Ring Light for ...   GH₵ 35.00
# 10   Lenovo HE01 BT 5.0 Neckband Wireless Earphones...   GH₵ 30.00
# 11   Tecno Spark Go 2021 - 32GB HDD - 2GB RAM Smart...  GH₵ 562.68
# 12   V9 Earhook Wireless Bluetooth Earphone CSR Noi...   GH₵ 34.00
# 13   M11 T-WS LCD Bluetooth 5.0 Wireless Headphones...   GH₵ 69.00
# 14   Wireless Bluetooth 5.0 Waterproof Headphones -...   GH₵ 43.00
# 15   Itel A16 Plus - 8GB HDD - 1GB RAM -  Phantom B...  GH₵ 251.00
# 16   Itel It 2173 Dual SIM Feature Phone - 512MB RO...   GH₵ 69.00
# 17   Itel A16 Plus - 8GB HDD - 1GB RAM - Champagne ...  GH₵ 251.00
# 18   Nokia C2-05 2GSM 2.0''  Slide Touch &Type Mp3 ...  GH₵ 139.00
# 19   X-INOVA Magic 6 Dual SIM Smartphone - 16GB HDD...  GH₵ 285.00
# 20   Nokia 105 (4th Edition) Dual SIM Cell Phone - ...  GH₵ 105.00
# 21   Nokia 110 (2019 Edition) Dual SIM Feature Phon...  GH₵ 185.00
# 22   X Tigi T1 Mini - 1.77" - Dual SIM Cell Phone -...   GH₵ 88.00
# 23   Itel 5081 Triple SIM Phone  Wireless FM Radio ...   GH₵ 97.00
# 24   Bontel Sleek Dual SIM Phone with FM Radio + FR...   GH₵ 83.00
# 25   Nokia 105 (4th Edition) Dual SIM Cell Phone - ...  GH₵ 105.00
# 26   Itel 2173 Dual Cell Phone - 512MB ROM - 512MB ...   GH₵ 90.00
# 27   Nokia Asha 210 Bluetooth Wi-Fi Mobile Phone -w...  GH₵ 175.00
# 28   Bontel Dual SIM Phone with FM Radio + FREE P47...   GH₵ 94.00
# 29             Nokia 5310 XpressMusic -  2.1 Inch Blue  GH₵ 130.00
# ..                                                 ...         ...
# 100  C3 Bluetooth 5.0 Wireless Headsets 10D Stereo ...   GH₵ 32.00
# 101  Itel A16 Plus - 8GB HDD - 1GB RAM -  Phantom B...  GH₵ 251.00
# 102  Wireless Bluetooth Earphone For iPhone Samsung...   GH₵ 33.00
# 103  Smart Bluetooth watches for ios and Android bands   GH₵ 30.00
# 104         Wireless Bluetooth Headset 2000mAh - Black   GH₵ 75.00
# 105   F9-32 Stereo V5.1 Bluetooth Earphone Power Banks   GH₵ 51.00
# 106  TWS Air Pro 6 Bluetooth Earphone Earbuds HiFi ...   GH₵ 58.00
# 107               Wireless Bluetooth Earphones - White   GH₵ 39.00
# 108  Samsung Galaxy A03 Core - 32GB HDD - 2GB RAM S...  GH₵ 554.00
# 109         IOOIOO Micro SD Memory Card - 32GB - Black   GH₵ 19.00
# 110                           New I5 Smartwatch - Pink   GH₵ 47.00
# 111  ARHANORY Tripod Stand with LED Ring Light for ...   GH₵ 35.00
# 112  Wireless Bluetooth 5.0 Waterproof Headphones -...   GH₵ 43.00
# 113  Lenovo HE01 BT 5.0 Neckband Wireless Earphones...   GH₵ 30.00
# 114  Lenovo XT90 BT5.0 True Wireless Headsets In-ea...   GH₵ 55.00
# 115      Heart Rate Sport Bracelet Smart Watch - Black   GH₵ 32.00
# 116    Color Screen Smart Bracelet Waterproof Bracelet   GH₵ 42.00
# 117    TCL L7 Smartphone  - 32GB HDD - 2GB RAM - Black  GH₵ 383.04
# 118  V9 Earhook Wireless Bluetooth Earphone CSR Noi...   GH₵ 34.00
# 119  M11 T-WS LCD Bluetooth 5.0 Wireless Headphones...   GH₵ 69.00
# 120    Smart Watch With Camera & SIM Card Slot - Black   GH₵ 65.00
# 121  3 in 1 Wireless Bluetooth Selfie Stick Foldabl...   GH₵ 35.00
# 122  TWS i12Tws Wireless Bluetooth 5.0 Sport Headse...   GH₵ 34.00
# 123  Bluetooth 5.0 Earphones 2200mAh Wireless Headp...   GH₵ 43.00
# 124  Color screen smart watch heart rate sport brac...   GH₵ 33.00
# 125                   Pro 6 Bluetooth Earphone - White   GH₵ 49.00
# 126  Bluetooth 4.0 Headset Universal V9 Business Wi...   GH₵ 29.00
# 127  T WS Bluetooth headset + ios smart watch water...   GH₵ 77.00
# 128  GT20 1.69 inch TFT Screen IP67 Waterproof Smar...  GH₵ 121.00
# 129  2Pcs Portable Speaker High-Volume Subwoofer US...   GH₵ 29.00
#
# [130 rows x 2 columns]
