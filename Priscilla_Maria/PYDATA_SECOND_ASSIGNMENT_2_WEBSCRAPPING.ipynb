# %%
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup as soup

# %%
url = 'https://www.jumia.com.gh/phones-tablets/'
url
# Out:
# 'https://www.jumia.com.gh/phones-tablets/'

# %%
request = Request(url,headers={'User-Agent': 'Mozilla/5.0'})
request

# %%
webpage = urlopen(request).read()

# %%
formatted_webpage = soup(webpage, "html.parser")

# %%
results = [pro.get_text() for pro in formatted_webpage .select(".core .name")]
results
# Out:
# ['Lenovo LP40 Wireless Earphone Bluetooth 5.0 Waterproof Earphone Touch headset white',
#  'TCL L7 Smartphone  - 32GB HDD - 2GB RAM - Black',
#  'P47 Wireless Foldable Bluetooth Headset -   Black',
#  'Itel A16 Plus - 8GB HDD - 1GB RAM -  Phantom Black + Free Gifts',
#  'Xiaomi Redmi 9A  Smartphone  -  32GB HDD - 2GB RAM -  Sky Blue',
#  'Samsung Micro SD Memory Card - 64GB - Red/White',
#  'ARHANORY Tripod Stand with LED Ring Light for Phones Laptop Plastic-Black',
#  '116Plus Digital Smart Watch 116 Plus- Black',
#  'F9 V5.1 Wireless Bluetooth Digital Display earphone -Black',
#  'Oraimo FreePods3 True Wireless Stereo Earbuds - Black',
#  'IOOIOO F9 Bluetooth Earbuds - Black',
#  'TWS i12Tws Wireless Bluetooth 5.0 Sport Headset - White',
#  'Itel It 2173 Dual SIM Feature Phone - 512MB ROM - 512MB RAM - Blue',
#  'MicroSDHC Card – 64GB Black',
#  'Air Pro 6 Bluetooth Headset 5.0 Stereo Sport Music Earphones With Mic For IOS Android IPhone',
#  'Lenovo LP40 Wireless Earphone Bluetooth 5.0 Waterproof Earphone Touch headset white',
#  'Bluetooth 5.0 Earphones 2200mAh Wireless Headphone',
#  'Itel A16 Plus - 8GB HDD - 1GB RAM -  Phantom Black + Free Gifts',
#  'ARHANORY Tripod Stand with LED Ring Light for Phones Laptop Plastic-Black',
#  'Lenovo LP40 Bluetooth 5.0 True Wireless Sport Headset -  White',
#  'Itel S16 Dual SIM Smartphone - 16GB HDD - 1GB RAM',
#  'F9-32 Stereo V5.1 Bluetooth Earphone Power Banks',
#  'Lenovo XT90 In-ear Earphones 5.0 Headphones True Wireless Earbuds with Touch Control',
#  'V9 Earhook Wireless Bluetooth Earphone CSR Noise Cancelling Earpiece Headset Portable',
#  'Pro 6 Bluetooth Earphone - White',
#  'Samsung Galaxy A125F/DS  -  128GB HDD  -  4GB RAM Smartphone  -  Black',
#  'F9 V5.1 Wireless Bluetooth Digital Display earphone -Black',
#  'Samsung Galaxy A22 Dual SIM  -  128GB HDD  -  4GB RAM Smartphone 5G  -  Violet',
#  'M11 T-WS LCD Bluetooth 5.0 Wireless Headphones - Black',
#  'Itel S16 Dual SIM Smartphone - 16GB HDD - 1GB RAM - Cosmic Shine',
#  'Itel A16 Plus - 8GB HDD - 1GB RAM -  Phantom Black + Free Gifts',
#  'Itel A16 Plus - 8GB HDD - 1GB RAM - Champagne Gold',
#  'Itel It 2173 Dual SIM Feature Phone - 512MB ROM - 512MB RAM - Blue',
#  'SOWHAT V4 - 8GB HDD - 1GB RAM Smartphone – Blue + 16GB SD Card',
#  'V3 - 8GB HDD - 1GB RAM Smartphone - Blue',
#  'Nokia 106 Dual SIM FM  Basic Phone - 1.8" - 4MB ROM - 4MB RAM - Black',
#  'X Tigi T1 Mini - 1.77" - Dual SIM Cell Phone - 32MB HDD- 32MB RAM - Blue',
#  'Nokia 105 (4th Edition) Dual SIM Cell Phone - Black',
#  'SOWHAT V3 Dual SIM - 8GB HDD - 1GB RAM Smartphone - Green',
#  'Nokia 5310 XpressMusic -  2.1 Inch Blue',
#  'X Tigi T1 - Walkie Talkie Telephone Tri SIM - 2.4" - 64MB - Black',
#  'X-INOVA Magic 4 - 16GB HDD - 2GB RAM - Blue',
#  'Nokia 215 2G 2.4" Cellphone Bluetooth Dual SIM 0.3MP GSM 900 /1800-- Black',
#  'Bontel Sleek Dual SIM Phone with FM Radio + FREE MP3 Player & Earpiece',
#  'Nokia Asha 210 Bluetooth Wi-Fi Mobile Phone -white',
#  'Itel S16 Dual SIM Smartphone - 16GB HDD - 1GB RAM',
#  'Infinix Smart HD X612 (2021) - 32GB HDD - 2GB RAM Smartphone -  Topaz Blue',
#  'TCL L7 Smartphone  - 32GB HDD - 2GB RAM - Black',
#  'Itel S16 Dual SIM Smartphone - 16GB HDD - 1GB RAM - Cosmic Shine',
#  'Tecno POP 3 (BB2) Dual SIM - 16GB HDD - 1GB RAM Smartphone - Champaign Gold',
#  'Itel S16 Dual SIM Smartphone - 16GB HDD - 1GB RAM - Dazzle Black',
#  'X-INOVA Magic 9 Dual SIM Smartphone - 16GB HDD - 2GB RAM - Black',
#  'TCL 20E Dual SIM - 32GB - 3GB RAM Smartphone - Blue',
#  'Xiaomi Redmi 9A  Smartphone  -  32GB HDD - 2GB RAM -  Sky Blue',
#  'TCL L7 Smartphone  - 32GB HDD - 2GB RAM - Black/Green',
#  'Apple IPhone 5S 16GB With Finger Sensor 4G LTE ( Gift ) Refurbiished',
#  'Anica T8 1.54 Inch 400mAh Ultra Thin Dual SIM Blu Black (bla',
#  'Amazon Kindle Fire HD 7 Kids Tablet - 16GB HDD - 1GB RAM -  7" - Red',
#  'Anica T8 1.54 Inch 400mAh Ultra Thin Dual SIM blu Gold (gold',
#  'X Tigi Hope8 LTE 4G Tablet - 32GB HDD - 2GB RAM- 8.0" - Dual SIM - Black',
#  'Lenovo LP40 Wireless Earphone Bluetooth 5.0 Waterproof Earphone Touch headset white',
#  'Bluetooth 5.0 Earphones 2200mAh Wireless Headphone',
#  'TWS Wireless Bluetooth Earphones - White',
#  'ARHANORY Tripod Stand with LED Ring Light for Phones Laptop Plastic-Black',
#  'Itel A16 Plus - 8GB HDD - 1GB RAM -  Phantom Black + Free Gifts',
#  'IOOIOO Micro SD Memory Card - 32GB - Black',
#  'Fingerprint Touch Noise-cancelling Stereo Bluetooth Headset - Black',
#  'Tripod Mobile phone Camera Foldable Stand Holder Table Smartphone Tripod',
#  'Wireless Bluetooth Earphone For iPhone, Samsung Pods - Black',
#  'Lenovo LP40 Bluetooth 5.0 True Wireless Sport Headset -  White',
#  'P47 Wireless Foldable Bluetooth Headset -   Black',
#  'Wireless Bluetooth Earphone For iPhone Samsung Pods - White',
#  'F9-32 Stereo V5.1 Bluetooth Earphone Power Banks',
#  'Lenovo XT90 In-ear Earphones 5.0 Headphones True Wireless Earbuds with Touch Control',
#  'V9 Earhook Wireless Bluetooth Earphone CSR Noise Cancelling Earpiece Headset Portable',
#  'Tripod Mobile phone Camera Foldable Stand Holder Table Smartphone Tripod',
#  'Oraimo OPB-P204D 20000mAh High Capacity Dual USB Output',
#  'F9-32 Stereo V5.1 Bluetooth Earphone Power Banks',
#  'V9 Earhook Wireless Bluetooth Earphone CSR Noise Cancelling Earpiece Headset Portable',
#  'Pro 6 Bluetooth Earphone - White',
#  '116Plus Digital Smart Watch 116 Plus- Black',
#  'Samsung Micro SD Memory Card - 64GB - Red/White',
#  'Oraimo FreePods3 True Wireless Stereo Earbuds - Black',
#  'TWS i12Tws Wireless Bluetooth 5.0 Sport Headset - White',
#  'MicroSDHC Card – 64GB Black',
#  'Color Screen Smart Bracelet Waterproof Bracelet',
#  'Wireless Bluetooth Earphone Earbuds HIFI Stereo Touch Sensor For Samsung IPhone Xiaomi Huawei',
#  'Universal 30,000mAh Inbuilt 3 in 1USB cable Powerbank - White',
#  'Lots of Function Waterproof smart watch-Light Pink',
#  'Lenovo XT92 Gaming Headset Low Latency Touch Bluetooth 5.1 Headset HiFi Stereo black',
#  'Itel It 2173 Dual SIM Feature Phone - 512MB ROM - 512MB RAM - Blue',
#  'X Tigi T1 Mini - 1.77" - Dual SIM Cell Phone - 32MB HDD- 32MB RAM - Blue',
#  'Nokia 105 (4th Edition) Dual SIM Cell Phone - Black',
#  'Itel 2160 Dual SIM Cell Phone - 32MB ROM\u200e - 32 MB RAM - Dark Blue',
#  'Nokia 110 (2019 Edition) Dual SIM Feature Phone - Black',
#  'Samsung B310E Dual SIM (SM-B310E) - Blue/Black',
#  'Tecno T301 Dual SIM - 4MB HDD - 4MB RAM - Gold + Free Extra Battery',
#  'Nokia 105 Dual SIM 4th Generation  - 32MB ROM\u200e - 4MB RAM Cell Phone - Black + Free 3310 Phone',
#  "Nokia C2-05 2GSM 2.0''  Slide Touch &Type Mp3 Player Mobile Phone",
#  'Itel 2173 Dual Cell Phone - 512MB ROM - 512MB RAM - Black/ Blue + Free Battery & Earpiece',
#  'Bontel Dual SIM Phone with FM Radio + FREE P47 Headphone  - Black/Multicolour',
#  'Itel 5081 Triple SIM Phone  Wireless FM Radio - Dark Blue',
#  'Nokia 105 (4th Edition) Dual SIM Cell Phone - Blue',
#  'X Tigi T1 - Walkie Talkie Telephone Tri SIM - 2.4" - 64MB - Black',
#  'Itel It 5606 Dual SIM - 4MB ROM - 4MB RAM - 2500mAh - Dark Blue',
#  'Lenovo LP40 Wireless Earphone Bluetooth 5.0 Waterproof Earphone Touch headset white',
#  'Bluetooth 5.0 Earphones 2200mAh Wireless Headphone',
#  'TWS Wireless Bluetooth Earphones - White',
#  'ARHANORY Tripod Stand with LED Ring Light for Phones Laptop Plastic-Black',
#  'Itel A16 Plus - 8GB HDD - 1GB RAM -  Phantom Black + Free Gifts',
#  'IOOIOO Micro SD Memory Card - 32GB - Black',
#  'Fingerprint Touch Noise-cancelling Stereo Bluetooth Headset - Black',
#  'Tripod Mobile phone Camera Foldable Stand Holder Table Smartphone Tripod',
#  'Wireless Bluetooth Earphone For iPhone, Samsung Pods - Black',
#  'Lenovo LP40 Bluetooth 5.0 True Wireless Sport Headset -  White',
#  'P47 Wireless Foldable Bluetooth Headset -   Black',
#  'Wireless Bluetooth Earphone For iPhone Samsung Pods - White',
#  'F9-32 Stereo V5.1 Bluetooth Earphone Power Banks',
#  'Lenovo XT90 In-ear Earphones 5.0 Headphones True Wireless Earbuds with Touch Control',
#  'V9 Earhook Wireless Bluetooth Earphone CSR Noise Cancelling Earpiece Headset Portable',
#  'Oraimo FreePods3 True Wireless Stereo Earbuds - Black',
#  '116 Plus Waterproof Smart Watch - Black',
#  'Pro 6 Bluetooth Earphone - White',
#  'Wireless Bluetooth Headset 2000mAh - Black',
#  'TWS Air Pro 6 Bluetooth Earphone Earbuds HiFi Stereo Touch Sensor Control Mic For Android & IOS',
#  'Itel S16 Dual SIM Smartphone - 16GB HDD - 1GB RAM',
#  'Wireless \u200bSpeakers AUX USB Bluetooth System Home Theater',
#  'Wireless Bluetooth Earphones - White',
#  'New I5 Smartwatch - Pink',
#  'Infinix Smart HD X612 (2021) - 32GB HDD - 2GB RAM Smartphone -  Topaz Blue',
#  '116Plus Digital Smart Watch 116 Plus- Black',
#  'Wireless Bluetooth Earphone For iPhone Samsung Pods - Pink',
#  'TCL L7 Smartphone  - 32GB HDD - 2GB RAM - Black',
#  'TWS i12Tws Wireless Bluetooth 5.0 Sport Headset - White',
#  'C3 Bluetooth 5.0 Wireless Headsets 10D Stereo Headphones With LED sports Earphone PRO3',
#  'Samsung Micro SD Memory Card - 64GB - Red/White',
#  'Smart Watch With Camera & SIM Card Slot - Black',
#  'F9 V5.1 Wireless Bluetooth Digital Display earphone -Black',
#  'M11 T-WS LCD Bluetooth 5.0 Wireless Headphones - Black',
#  'Lenovo XT92 Gaming Headset Low Latency Touch Bluetooth 5.1 Headset HiFi Stereo black',
#  'Smart Bluetooth watches for ios and Android bands',
#  '9H Nano Liquid Screen Protector for all Smartphones/tablets/Smart watches',
#  'Air Pro 6 Bluetooth Headset 5.0 Stereo Sport Music Earphones With Mic For IOS Android IPhone',
#  'Bluetooth 4.0 Headset Universal V9 Business Wireless',
#  '2Pcs Portable Speaker High-Volume Subwoofer USB-Black',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
price = [cost.get_text() for cost in formatted_webpage .select(".core .prc")]
price
# Out:
# ['GH₵ 61.44',
#  'GH₵ 383.04',
#  'GH₵ 28.00',
#  'GH₵ 268.18',
#  'GH₵ 686.36',
#  'GH₵ 48.00',
#  'GH₵ 33.60',
#  'GH₵ 35.00',
#  'GH₵ 65.00',
#  'GH₵ 168.96',
#  'GH₵ 65.00',
#  'GH₵ 32.98',
#  'GH₵ 86.33',
#  'GH₵ 46.50',
#  'GH₵ 49.00',
#  'GH₵ 61.44',
#  'GH₵ 43.00',
#  'GH₵ 268.18',
#  'GH₵ 33.60',
#  'GH₵ 65.00',
#  'GH₵ 454.55',
#  'GH₵ 53.76',
#  'GH₵ 55.00',
#  'GH₵ 37.00',
#  'GH₵ 49.00',
#  'GH₵ 1,064.77',
#  'GH₵ 65.00',
#  'GH₵ 1,395.46',
#  'GH₵ 65.00',
#  'GH₵ 454.55',
#  'GH₵ 268.18',
#  'GH₵ 268.18',
#  'GH₵ 86.33',
#  'GH₵ 240.00',
#  'GH₵ 242.50',
#  'GH₵ 82.00',
#  'GH₵ 88.00',
#  'GH₵ 121.00',
#  'GH₵ 230.00',
#  'GH₵ 142.00',
#  'GH₵ 159.00',
#  'GH₵ 260.00',
#  'GH₵ 138.00',
#  'GH₵ 81.00',
#  'GH₵ 192.00',
#  'GH₵ 454.55',
#  'GH₵ 604.00',
#  'GH₵ 383.04',
#  'GH₵ 454.55',
#  'GH₵ 558.57',
#  'GH₵ 432.00',
#  'GH₵ 310.40',
#  'GH₵ 605.00',
#  'GH₵ 686.36',
#  'GH₵ 385.00',
#  'GH₵ 482.00',
#  'GH₵ 369.00',
#  'GH₵ 577.15',
#  'GH₵ 429.00',
#  'GH₵ 569.00',
#  'GH₵ 61.44',
#  'GH₵ 43.00',
#  'GH₵ 38.80',
#  'GH₵ 33.60',
#  'GH₵ 268.18',
#  'GH₵ 19.00',
#  'GH₵ 29.00',
#  'GH₵ 49.00',
#  'GH₵ 37.00',
#  'GH₵ 65.00',
#  'GH₵ 28.00',
#  'GH₵ 36.00',
#  'GH₵ 53.76',
#  'GH₵ 55.00',
#  'GH₵ 37.00',
#  'GH₵ 49.00',
#  'GH₵ 102.38',
#  'GH₵ 53.76',
#  'GH₵ 37.00',
#  'GH₵ 49.00',
#  'GH₵ 35.00',
#  'GH₵ 48.00',
#  'GH₵ 168.96',
#  'GH₵ 32.98',
#  'GH₵ 46.50',
#  'GH₵ 48.00',
#  'GH₵ 58.00',
#  'GH₵ 75.85',
#  'GH₵ 77.76',
#  'GH₵ 71.00',
#  'GH₵ 86.33',
#  'GH₵ 88.00',
#  'GH₵ 121.00',
#  'GH₵ 90.00',
#  'GH₵ 180.38',
#  'GH₵ 189.00',
#  'GH₵ 130.00',
#  'GH₵ 210.00',
#  'GH₵ 142.00',
#  'GH₵ 98.00',
#  'GH₵ 94.00',
#  'GH₵ 115.00',
#  'GH₵ 121.00',
#  'GH₵ 159.00',
#  'GH₵ 80.00',
#  'GH₵ 61.44',
#  'GH₵ 43.00',
#  'GH₵ 38.80',
#  'GH₵ 33.60',
#  'GH₵ 268.18',
#  'GH₵ 19.00',
#  'GH₵ 29.00',
#  'GH₵ 49.00',
#  'GH₵ 37.00',
#  'GH₵ 65.00',
#  'GH₵ 28.00',
#  'GH₵ 36.00',
#  'GH₵ 53.76',
#  'GH₵ 55.00',
#  'GH₵ 37.00',
#  'GH₵ 168.96',
#  'GH₵ 34.00',
#  'GH₵ 49.00',
#  'GH₵ 60.00',
#  'GH₵ 57.60',
#  'GH₵ 454.55',
#  'GH₵ 169.21',
#  'GH₵ 39.00',
#  'GH₵ 51.00',
#  'GH₵ 604.00',
#  'GH₵ 35.00',
#  'GH₵ 37.00',
#  'GH₵ 383.04',
#  'GH₵ 32.98',
#  'GH₵ 32.00',
#  'GH₵ 48.00',
#  'GH₵ 71.00',
#  'GH₵ 65.00',
#  'GH₵ 65.00',
#  'GH₵ 71.00',
#  'GH₵ 32.00',
#  'GH₵ 9.14',
#  'GH₵ 49.00',
#  'GH₵ 32.00',
#  'GH₵ 32.00',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "name" : results,
    "Price" : price,})
df
# Out:
#                                                   name       Price
# 0    Lenovo LP40 Wireless Earphone Bluetooth 5.0 Wa...   GH₵ 61.44
# 1      TCL L7 Smartphone  - 32GB HDD - 2GB RAM - Black  GH₵ 383.04
# 2    P47 Wireless Foldable Bluetooth Headset -   Black   GH₵ 28.00
# 3    Itel A16 Plus - 8GB HDD - 1GB RAM -  Phantom B...  GH₵ 268.18
# 4    Xiaomi Redmi 9A  Smartphone  -  32GB HDD - 2GB...  GH₵ 686.36
# ..                                                 ...         ...
# 148
# 149
# 150
# 151
# 152
#
# [153 rows x 2 columns]

# %%
df.to_csv('Asignment2_results.csv')
